# %% [markdown]
# <a href="https://colab.research.google.com/github/bavasilev/Project_demo/blob/main/50k_v_sumke.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")

# %%
print("Kukar_DauN")
# Out:
# Kukar_DauN

# %% [markdown]
# suka blaдь

# %%
print()

# %%
print("proverka")
# Out:
# proverka

# %% [markdown]
# ![Pog_Rizitaz.jpg](data:image/jpeg;base64,...)

# %%
print("иди нахуй")

# %%
print("х")
